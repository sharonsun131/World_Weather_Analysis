# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities: 
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
# Import the API key.
from config import weather_api_key

import json
import time

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 1. Create an empty list to hold the weather data 
city_data = []

# Print the beginning of the logging 
print(f'Beginning Data Retrieval     ')
print("------------------------------")

# create counters 
record_count=1
set_count= 1
# 2. # Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description= city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | souillac
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | sinnamary
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | hamilton
# Processing Record 8 of Set 1 | soacha
# Processing Record 9 of Set 1 | viedma
# Processing Record 10 of Set 1 | torbay
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | longyearbyen
# Processing Record 14 of Set 1 | garowe
# Processing Record 15 of Set 1 | touros
# Processing Record 16 of Set 1 | jumla
# Processing Record 17 of Set 1 | berlin
# Processing Record 18 of Set 1 | huallanca
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | orange walk
# Processing Record 21 of Set 1 | nara
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | clocolan
# Processing Record 27 of Set 1 | kanye
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | vestmannaeyjar
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | panama city
# Processing Record 35 of Set 1 | bandarbeyla
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | vila do maio
# Processing Record 38 of Set 1 | hooksett
# Processing Record 39 of Set 1 | tabuk
# Processing Record 40 of Set 1 | daura
# Processing Record 41 of Set 1 | ornskoldsvik
# Processing Record 42 of Set 1 | marsaxlokk
# Processing Record 43 of Set 1 | belyy yar
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | nicoya
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | sur
# Processing Record 49 of Set 1 | livramento
# Processing Record 50 of Set 1 | carutapera
# Processing Record 1 of Set 2 | eldorado
# Processing Record 2 of Set 2 | quelimane
# Processing Record 3 of Set 2 | laguna
# Processing Record 4 of Set 2 | pangnirtung
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | banda aceh
# Processing Record 7 of Set 2 | san pedro
# Processing Record 8 of Set 2 | praia da vitoria
# Processing Record 9 of Set 2 | malaya purga
# Processing Record 10 of Set 2 | turbat
# Processing Record 11 of Set 2 | betioky
# Processing Record 12 of Set 2 | sembabule
# Processing Record 13 of Set 2 | chuy
# Processing Record 14 of Set 2 | ponta do sol
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | araouane
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | bathsheba
# Processing Record 20 of Set 2 | dolzhanskaya
# Processing Record 21 of Set 2 | montepuez
# Processing Record 22 of Set 2 | vagamo
# Processing Record 23 of Set 2 | ostrovnoy
# Processing Record 24 of Set 2 | kirkland lake
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | taoudenni
# Processing Record 27 of Set 2 | carballo
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | chhabra
# Processing Record 30 of Set 2 | patacamaya
# Processing Record 31 of Set 2 | mitu
# Processing Record 32 of Set 2 | csabacsud
# City not found. Skipping...
# Processing Record 33 of Set 2 | isiro
# Processing Record 34 of Set 2 | omboue
# Processing Record 35 of Set 2 | salalah
# Processing Record 36 of Set 2 | atar
# Processing Record 37 of Set 2 | manta
# Processing Record 38 of Set 2 | saquarema
# Processing Record 39 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 2 | mitsamiouli
# Processing Record 41 of Set 2 | manoharpur
# Processing Record 42 of Set 2 | mirebalais
# Processing Record 43 of Set 2 | ancud
# Processing Record 44 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 2 | trapani
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | chiredzi
# Processing Record 48 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 2 | narsaq
# Processing Record 1 of Set 3 | bhabua
# Processing Record 2 of Set 3 | east london
# Processing Record 3 of Set 3 | thinadhoo
# Processing Record 4 of Set 3 | fianarantsoa
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | los llanos de aridane
# Processing Record 7 of Set 3 | kaura namoda
# Processing Record 8 of Set 3 | north myrtle beach
# Processing Record 9 of Set 3 | walvis bay
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | harindanga
# Processing Record 12 of Set 3 | kargasok
# Processing Record 13 of Set 3 | andra
# Processing Record 14 of Set 3 | kostrzyn
# Processing Record 15 of Set 3 | bethanien
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | santa cruz
# Processing Record 18 of Set 3 | padang
# Processing Record 19 of Set 3 | chake chake
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | molodizhne
# Processing Record 22 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 23 of Set 3 | bayonet point
# Processing Record 24 of Set 3 | necochea
# Processing Record 25 of Set 3 | dingle
# Processing Record 26 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 27 of Set 3 | natal
# Processing Record 28 of Set 3 | monrovia
# Processing Record 29 of Set 3 | marawi
# Processing Record 30 of Set 3 | jales
# Processing Record 31 of Set 3 | pori
# Processing Record 32 of Set 3 | maldonado
# Processing Record 33 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 3 | comodoro rivadavia
# Processing Record 35 of Set 3 | angoche
# Processing Record 36 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 37 of Set 3 | ullapool
# Processing Record 38 of Set 3 | maniitsoq
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | oranjemund
# Processing Record 41 of Set 3 | nantucket
# Processing Record 42 of Set 3 | vreed en hoop
# City not found. Skipping...
# Processing Record 43 of Set 3 | ust-charyshskaya pristan
# Processing Record 44 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 45 of Set 3 | matay
# Processing Record 46 of Set 3 | raga
# Processing Record 47 of Set 3 | kindu
# Processing Record 48 of Set 3 | quatre cocos
# Processing Record 49 of Set 3 | chapais
# Processing Record 50 of Set 3 | polunochnoye
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | cayenne
# Processing Record 3 of Set 4 | desbiens
# Processing Record 4 of Set 4 | kangaatsiaq
# Processing Record 5 of Set 4 | itaitinga
# Processing Record 6 of Set 4 | tazovskiy
# Processing Record 7 of Set 4 | puntarenas
# Processing Record 8 of Set 4 | codrington
# Processing Record 9 of Set 4 | ambovombe
# Processing Record 10 of Set 4 | klaksvik
# Processing Record 11 of Set 4 | jacmel
# Processing Record 12 of Set 4 | sumbe
# Processing Record 13 of Set 4 | saint george
# Processing Record 14 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 4 | carauari
# Processing Record 16 of Set 4 | henties bay
# Processing Record 17 of Set 4 | prieska
# Processing Record 18 of Set 4 | mian channun
# Processing Record 19 of Set 4 | verkhnyaya inta
# Processing Record 20 of Set 4 | saint anthony
# Processing Record 21 of Set 4 | bilma
# Processing Record 22 of Set 4 | taltal
# Processing Record 23 of Set 4 | semnan
# Processing Record 24 of Set 4 | kruisfontein
# Processing Record 25 of Set 4 | eyl
# Processing Record 26 of Set 4 | bartica
# Processing Record 27 of Set 4 | bambous virieux
# Processing Record 28 of Set 4 | macau
# Processing Record 29 of Set 4 | saint-augustin
# Processing Record 30 of Set 4 | turukhansk
# Processing Record 31 of Set 4 | sao jose da coroa grande
# Processing Record 32 of Set 4 | pytalovo
# Processing Record 33 of Set 4 | kavaratti
# Processing Record 34 of Set 4 | balkhash
# Processing Record 35 of Set 4 | havre-saint-pierre
# Processing Record 36 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 4 | beloha
# Processing Record 38 of Set 4 | mahebourg
# Processing Record 39 of Set 4 | jos
# Processing Record 40 of Set 4 | giyon
# Processing Record 41 of Set 4 | lokosovo
# Processing Record 42 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 4 | rio grande
# Processing Record 44 of Set 4 | rzhaksa
# Processing Record 45 of Set 4 | acin
# City not found. Skipping...
# Processing Record 46 of Set 4 | marfino
# Processing Record 47 of Set 4 | tabou
# Processing Record 48 of Set 4 | tessalit
# Processing Record 49 of Set 4 | olafsvik
# Processing Record 50 of Set 4 | namibe
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | jinka
# Processing Record 3 of Set 5 | cururupu
# Processing Record 4 of Set 5 | ovruch
# Processing Record 5 of Set 5 | plettenberg bay
# Processing Record 6 of Set 5 | caconda
# Processing Record 7 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 5 | kasempa
# Processing Record 9 of Set 5 | lagunas
# Processing Record 10 of Set 5 | osorno
# Processing Record 11 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 5 | zetaquira
# Processing Record 13 of Set 5 | buchanan
# Processing Record 14 of Set 5 | antofagasta
# Processing Record 15 of Set 5 | ilulissat
# Processing Record 16 of Set 5 | manjacaze
# Processing Record 17 of Set 5 | ylivieska
# Processing Record 18 of Set 5 | ormara
# Processing Record 19 of Set 5 | coquimbo
# Processing Record 20 of Set 5 | korla
# Processing Record 21 of Set 5 | hambantota
# Processing Record 22 of Set 5 | senanga
# Processing Record 23 of Set 5 | shieli
# Processing Record 24 of Set 5 | tiznit
# Processing Record 25 of Set 5 | rawson
# Processing Record 26 of Set 5 | kisangani
# Processing Record 27 of Set 5 | kerman
# Processing Record 28 of Set 5 | balkanabat
# Processing Record 29 of Set 5 | port shepstone
# Processing Record 30 of Set 5 | spetsai
# City not found. Skipping...
# Processing Record 31 of Set 5 | cartagena del chaira
# Processing Record 32 of Set 5 | sol-iletsk
# Processing Record 33 of Set 5 | riohacha
# Processing Record 34 of Set 5 | nandigama
# Processing Record 35 of Set 5 | marsh harbour
# Processing Record 36 of Set 5 | qostanay
# Processing Record 37 of Set 5 | copiapo
# Processing Record 38 of Set 5 | new waterford
# Processing Record 39 of Set 5 | faya
# Processing Record 40 of Set 5 | takoradi
# Processing Record 41 of Set 5 | puerto narino
# Processing Record 42 of Set 5 | bhainsdehi
# Processing Record 43 of Set 5 | kismayo
# Processing Record 44 of Set 5 | huarmey
# Processing Record 45 of Set 5 | berlevag
# Processing Record 46 of Set 5 | vardo
# Processing Record 47 of Set 5 | nanortalik
# Processing Record 48 of Set 5 | sitges
# Processing Record 49 of Set 5 | nuuk
# Processing Record 50 of Set 5 | mercedes
# Processing Record 1 of Set 6 | amapa
# Processing Record 2 of Set 6 | baglung
# Processing Record 3 of Set 6 | japura
# Processing Record 4 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 6 | spartanburg
# Processing Record 6 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 6 | cachoeira do sul
# Processing Record 8 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 6 | sept-iles
# Processing Record 11 of Set 6 | sao filipe
# Processing Record 12 of Set 6 | port-de-bouc
# Processing Record 13 of Set 6 | radviliskis
# Processing Record 14 of Set 6 | koroni
# Processing Record 15 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 16 of Set 6 | aarup
# City not found. Skipping...
# Processing Record 17 of Set 6 | bertoua
# Processing Record 18 of Set 6 | leeuwarden
# Processing Record 19 of Set 6 | praia
# Processing Record 20 of Set 6 | geraldton
# Processing Record 21 of Set 6 | verrettes
# Processing Record 22 of Set 6 | pitimbu
# Processing Record 23 of Set 6 | abonnema
# Processing Record 24 of Set 6 | callaway
# Processing Record 25 of Set 6 | sciacca
# Processing Record 26 of Set 6 | muros
# Processing Record 27 of Set 6 | newcastle
# Processing Record 28 of Set 6 | havoysund
# Processing Record 29 of Set 6 | conceicao do araguaia
# Processing Record 30 of Set 6 | umm kaddadah
# Processing Record 31 of Set 6 | umba
# Processing Record 32 of Set 6 | acarau
# Processing Record 33 of Set 6 | sars
# Processing Record 34 of Set 6 | charlestown
# Processing Record 35 of Set 6 | saint-francois
# Processing Record 36 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 37 of Set 6 | ambilobe
# Processing Record 38 of Set 6 | coaticook
# Processing Record 39 of Set 6 | porto velho
# Processing Record 40 of Set 6 | moose factory
# Processing Record 41 of Set 6 | margate
# Processing Record 42 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 43 of Set 6 | salinopolis
# Processing Record 44 of Set 6 | methoni
# Processing Record 45 of Set 6 | aksarka
# Processing Record 46 of Set 6 | rock sound
# Processing Record 47 of Set 6 | cidreira
# Processing Record 48 of Set 6 | meulaboh
# Processing Record 49 of Set 6 | cabedelo
# Processing Record 50 of Set 6 | belmonte
# Processing Record 1 of Set 7 | tupa
# Processing Record 2 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 3 of Set 7 | rio claro
# Processing Record 4 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 7 | takab
# Processing Record 6 of Set 7 | puerto del rosario
# Processing Record 7 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 7 | lorenfallet
# City not found. Skipping...
# Processing Record 9 of Set 7 | kalmunai
# Processing Record 10 of Set 7 | bougouni
# Processing Record 11 of Set 7 | kapuskasing
# Processing Record 12 of Set 7 | sikasso
# Processing Record 13 of Set 7 | lar gerd
# City not found. Skipping...
# Processing Record 14 of Set 7 | cusuna
# Processing Record 15 of Set 7 | kamenka
# Processing Record 16 of Set 7 | awbari
# Processing Record 17 of Set 7 | sal rei
# Processing Record 18 of Set 7 | bollnas
# Processing Record 19 of Set 7 | roald
# Processing Record 20 of Set 7 | mahon
# Processing Record 21 of Set 7 | nowy dwor mazowiecki
# Processing Record 22 of Set 7 | abay
# Processing Record 23 of Set 7 | macroom
# Processing Record 24 of Set 7 | temyasovo
# Processing Record 25 of Set 7 | marsa matruh
# Processing Record 26 of Set 7 | pervomayskiy
# Processing Record 27 of Set 7 | salacgriva
# Processing Record 28 of Set 7 | gorshechnoye
# Processing Record 29 of Set 7 | paamiut
# Processing Record 30 of Set 7 | weymouth
# Processing Record 31 of Set 7 | killybegs
# Processing Record 32 of Set 7 | iquique
# Processing Record 33 of Set 7 | inongo
# Processing Record 34 of Set 7 | reinosa
# Processing Record 35 of Set 7 | saint-joseph
# Processing Record 36 of Set 7 | hebertville
# City not found. Skipping...
# Processing Record 37 of Set 7 | skibbereen
# Processing Record 38 of Set 7 | san juan
# Processing Record 39 of Set 7 | abeche
# Processing Record 40 of Set 7 | niquero
# Processing Record 41 of Set 7 | sisimiut
# Processing Record 42 of Set 7 | aswan
# Processing Record 43 of Set 7 | channel-port aux basques
# Processing Record 44 of Set 7 | passagem franca
# Processing Record 45 of Set 7 | middelkerke
# Processing Record 46 of Set 7 | bauchi
# Processing Record 47 of Set 7 | kosa
# Processing Record 48 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 49 of Set 7 | lardos
# Processing Record 50 of Set 7 | jiblah
# Processing Record 1 of Set 8 | shalya
# Processing Record 2 of Set 8 | lagoa
# Processing Record 3 of Set 8 | hargeysa
# Processing Record 4 of Set 8 | qunduz
# Processing Record 5 of Set 8 | colares
# Processing Record 6 of Set 8 | camana
# Processing Record 7 of Set 8 | manyana
# Processing Record 8 of Set 8 | hemnesberget
# Processing Record 9 of Set 8 | gao
# Processing Record 10 of Set 8 | george
# Processing Record 11 of Set 8 | merrill
# Processing Record 12 of Set 8 | clyde river
# Processing Record 13 of Set 8 | san luis
# Processing Record 14 of Set 8 | luderitz
# Processing Record 15 of Set 8 | bridlington
# Processing Record 16 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 17 of Set 8 | abu kamal
# Processing Record 18 of Set 8 | hrodna
# Processing Record 19 of Set 8 | guane
# Processing Record 20 of Set 8 | djibo
# Processing Record 21 of Set 8 | albany
# Processing Record 22 of Set 8 | mao
# Processing Record 23 of Set 8 | yelanskiy
# Processing Record 24 of Set 8 | hofn
# Processing Record 25 of Set 8 | camacha
# Processing Record 26 of Set 8 | la rioja
# Processing Record 27 of Set 8 | nouadhibou
# Processing Record 28 of Set 8 | arlit
# Processing Record 29 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 30 of Set 8 | naxos
# Processing Record 31 of Set 8 | hualmay
# Processing Record 32 of Set 8 | rincon
# Processing Record 33 of Set 8 | asaka
# Processing Record 34 of Set 8 | gurdaha
# Processing Record 35 of Set 8 | kumluca
# Processing Record 36 of Set 8 | burica
# City not found. Skipping...
# Processing Record 37 of Set 8 | urengoy
# Processing Record 38 of Set 8 | jawhar
# Processing Record 39 of Set 8 | sechura
# Processing Record 40 of Set 8 | veraval
# Processing Record 41 of Set 8 | vallenar
# Processing Record 42 of Set 8 | tapes
# Processing Record 43 of Set 8 | itacare
# Processing Record 44 of Set 8 | minsk
# Processing Record 45 of Set 8 | osmaniye
# Processing Record 46 of Set 8 | jacqueville
# Processing Record 47 of Set 8 | oranjestad
# Processing Record 48 of Set 8 | constitucion
# Processing Record 49 of Set 8 | keetmanshoop
# Processing Record 50 of Set 8 | raudeberg
# Processing Record 1 of Set 9 | cachira
# Processing Record 2 of Set 9 | yarmouth
# Processing Record 3 of Set 9 | obuasi
# Processing Record 4 of Set 9 | taman
# Processing Record 5 of Set 9 | zlobin
# Processing Record 6 of Set 9 | tukrah
# Processing Record 7 of Set 9 | evanton
# Processing Record 8 of Set 9 | workington
# Processing Record 9 of Set 9 | abha
# Processing Record 10 of Set 9 | acari
# Processing Record 11 of Set 9 | pisco
# Processing Record 12 of Set 9 | requena
# Processing Record 13 of Set 9 | catamayo
# Processing Record 14 of Set 9 | upata
# Processing Record 15 of Set 9 | mangrol
# Processing Record 16 of Set 9 | tabas
# Processing Record 17 of Set 9 | koutiala
# Processing Record 18 of Set 9 | kedougou
# Processing Record 19 of Set 9 | pryozerne
# Processing Record 20 of Set 9 | batouri
# Processing Record 21 of Set 9 | marystown
# Processing Record 22 of Set 9 | pakruojis
# Processing Record 23 of Set 9 | san carlos
# Processing Record 24 of Set 9 | moroto
# Processing Record 25 of Set 9 | burevestnik
# Processing Record 26 of Set 9 | bogandinskiy
# Processing Record 27 of Set 9 | carmo
# Processing Record 28 of Set 9 | kortkeros
# Processing Record 29 of Set 9 | blagoyevo
# Processing Record 30 of Set 9 | kozhva
# Processing Record 31 of Set 9 | cerro largo
# Processing Record 32 of Set 9 | tallahassee
# Processing Record 33 of Set 9 | surt
# Processing Record 34 of Set 9 | yozgat
# Processing Record 35 of Set 9 | boa vista
# Processing Record 36 of Set 9 | canico
# Processing Record 37 of Set 9 | rabo de peixe
# Processing Record 38 of Set 9 | helmstedt
# Processing Record 39 of Set 9 | lodja
# Processing Record 40 of Set 9 | shemonaikha
# Processing Record 41 of Set 9 | puerto colombia
# Processing Record 42 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 43 of Set 9 | armacao de pera
# Processing Record 44 of Set 9 | lisakovsk
# Processing Record 45 of Set 9 | kjollefjord
# Processing Record 46 of Set 9 | ugra
# Processing Record 47 of Set 9 | chinchani
# Processing Record 48 of Set 9 | mecca
# Processing Record 49 of Set 9 | mutoko
# Processing Record 50 of Set 9 | crnici
# Processing Record 1 of Set 10 | biltine
# Processing Record 2 of Set 10 | mopipi
# Processing Record 3 of Set 10 | mangai
# Processing Record 4 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 5 of Set 10 | vigrestad
# Processing Record 6 of Set 10 | gornyy
# Processing Record 7 of Set 10 | berbera
# Processing Record 8 of Set 10 | rottweil
# Processing Record 9 of Set 10 | mapiri
# Processing Record 10 of Set 10 | santiago del estero
# Processing Record 11 of Set 10 | kuybyshevskiy zaton
# Processing Record 12 of Set 10 | valparaiso
# Processing Record 13 of Set 10 | divnomorskoye
# Processing Record 14 of Set 10 | ust-tsilma
# Processing Record 15 of Set 10 | severnoye
# Processing Record 16 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 10 | termoli
# Processing Record 18 of Set 10 | agirish
# Processing Record 19 of Set 10 | carlos chagas
# Processing Record 20 of Set 10 | altay
# Processing Record 21 of Set 10 | waycross
# Processing Record 22 of Set 10 | mayumba
# Processing Record 23 of Set 10 | semey
# Processing Record 24 of Set 10 | koson
# Processing Record 25 of Set 10 | bukama
# Processing Record 26 of Set 10 | crotone
# Processing Record 27 of Set 10 | port-gentil
# Processing Record 28 of Set 10 | afgoye
# City not found. Skipping...
# Processing Record 29 of Set 10 | gualaquiza
# Processing Record 30 of Set 10 | kemijarvi
# Processing Record 31 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 10 | galle
# Processing Record 33 of Set 10 | husavik
# Processing Record 34 of Set 10 | gazli
# Processing Record 35 of Set 10 | iqaluit
# Processing Record 36 of Set 10 | fenoarivo
# Processing Record 37 of Set 10 | jacareacanga
# Processing Record 38 of Set 10 | warmbad
# Processing Record 39 of Set 10 | rocha
# Processing Record 40 of Set 10 | asosa
# Processing Record 41 of Set 10 | baijiantan
# Processing Record 42 of Set 10 | kota
# Processing Record 43 of Set 10 | sokoni
# Processing Record 44 of Set 10 | mingaora
# Processing Record 45 of Set 10 | gamba
# Processing Record 46 of Set 10 | pafos
# Processing Record 47 of Set 10 | minudasht
# Processing Record 48 of Set 10 | gat
# Processing Record 49 of Set 10 | sanchursk
# Processing Record 50 of Set 10 | mvuma
# Processing Record 1 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 2 of Set 11 | aksu
# Processing Record 3 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 4 of Set 11 | beira
# Processing Record 5 of Set 11 | conde
# Processing Record 6 of Set 11 | porto santo
# Processing Record 7 of Set 11 | murwara
# Processing Record 8 of Set 11 | gaspe
# Processing Record 9 of Set 11 | zonguldak
# Processing Record 10 of Set 11 | goderich
# Processing Record 11 of Set 11 | kangaba
# Processing Record 12 of Set 11 | hanover
# Processing Record 13 of Set 11 | abu samrah
# Processing Record 14 of Set 11 | tucupita
# Processing Record 15 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 16 of Set 11 | caravelas
# Processing Record 17 of Set 11 | shakawe
# Processing Record 18 of Set 11 | nova prata
# Processing Record 19 of Set 11 | montemor-o-novo
# Processing Record 20 of Set 11 | sinjar
# Processing Record 21 of Set 11 | santa isabel do rio negro
# Processing Record 22 of Set 11 | cozumel
# Processing Record 23 of Set 11 | ugoofaaru
# Processing Record 24 of Set 11 | lipari
# Processing Record 25 of Set 11 | adoni
# Processing Record 26 of Set 11 | marabba
# Processing Record 27 of Set 11 | beziers
# Processing Record 28 of Set 11 | grand gaube
# Processing Record 29 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 11 | surgut
# Processing Record 31 of Set 11 | goianesia
# Processing Record 32 of Set 11 | vurnary
# Processing Record 33 of Set 11 | almazar
# Processing Record 34 of Set 11 | itaqui
# Processing Record 35 of Set 11 | itarema
# Processing Record 36 of Set 11 | mana
# Processing Record 37 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 38 of Set 11 | lerwick
# Processing Record 39 of Set 11 | kurtalan
# Processing Record 40 of Set 11 | great yarmouth
# Processing Record 41 of Set 11 | ishlei
# City not found. Skipping...
# Processing Record 42 of Set 11 | halmstad
# Processing Record 43 of Set 11 | cap malheureux
# Processing Record 44 of Set 11 | liverpool
# Processing Record 45 of Set 11 | uige
# Processing Record 46 of Set 11 | kakonko
# Processing Record 47 of Set 11 | prainha
# Processing Record 48 of Set 11 | dagana
# Processing Record 49 of Set 11 | corbelia
# Processing Record 50 of Set 11 | stornoway
# Processing Record 1 of Set 12 | freetown
# Processing Record 2 of Set 12 | agadez
# Processing Record 3 of Set 12 | muisne
# Processing Record 4 of Set 12 | biscarrosse
# Processing Record 5 of Set 12 | marrakesh
# Processing Record 6 of Set 12 | wattegama
# Processing Record 7 of Set 12 | sassandra
# Processing Record 8 of Set 12 | bonito
# Processing Record 9 of Set 12 | sjovegan
# Processing Record 10 of Set 12 | chimbote
# Processing Record 11 of Set 12 | wick
# Processing Record 12 of Set 12 | americana
# Processing Record 13 of Set 12 | caala
# Processing Record 14 of Set 12 | naliya
# Processing Record 15 of Set 12 | esil
# Processing Record 16 of Set 12 | maraa
# Processing Record 17 of Set 12 | aquiraz
# Processing Record 18 of Set 12 | makat
# Processing Record 19 of Set 12 | shrewsbury
# Processing Record 20 of Set 12 | peniche
# Processing Record 21 of Set 12 | santa fe
# Processing Record 22 of Set 12 | port-cartier
# Processing Record 23 of Set 12 | vicuna
# Processing Record 24 of Set 12 | lewisporte
# Processing Record 25 of Set 12 | raseiniai
# Processing Record 26 of Set 12 | santa rosa
# Processing Record 27 of Set 12 | shahr-e babak
# Processing Record 28 of Set 12 | quartucciu
# Processing Record 29 of Set 12 | nageshwari
# Processing Record 30 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 12 | mul
# Processing Record 32 of Set 12 | lulea
# Processing Record 33 of Set 12 | grand-santi
# Processing Record 34 of Set 12 | hlukhiv
# Processing Record 35 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 36 of Set 12 | yambio
# Processing Record 37 of Set 12 | puerto suarez
# Processing Record 38 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 39 of Set 12 | axim
# Processing Record 40 of Set 12 | ribeira brava
# Processing Record 41 of Set 12 | bisira
# Processing Record 42 of Set 12 | opuwo
# Processing Record 43 of Set 12 | sambava
# Processing Record 44 of Set 12 | saint-leu
# Processing Record 45 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 12 | santa maria
# Processing Record 47 of Set 12 | krasnoarmeyskiy
# Processing Record 48 of Set 12 | pemba
# Processing Record 49 of Set 12 | capreol
# Processing Record 50 of Set 12 | grindavik
# Processing Record 1 of Set 13 | baghmara
# Processing Record 2 of Set 13 | tremedal
# Processing Record 3 of Set 13 | batken
# Processing Record 4 of Set 13 | kalmar
# Processing Record 5 of Set 13 | mugumu
# Processing Record 6 of Set 13 | rudsar
# Processing Record 7 of Set 13 | kudahuvadhoo
# Processing Record 8 of Set 13 | talnakh
# Processing Record 9 of Set 13 | konstantinovsk
# Processing Record 10 of Set 13 | ruwi
# Processing Record 11 of Set 13 | panaba
# Processing Record 12 of Set 13 | pratapgarh
# Processing Record 13 of Set 13 | andenes
# Processing Record 14 of Set 13 | morondava
# Processing Record 15 of Set 13 | nikolsk
# Processing Record 16 of Set 13 | macherla
# Processing Record 17 of Set 13 | joshimath
# Processing Record 18 of Set 13 | dalton
# Processing Record 19 of Set 13 | bellegarde-sur-valserine
# Processing Record 20 of Set 13 | adrar
# Processing Record 21 of Set 13 | kamskiye polyany
# Processing Record 22 of Set 13 | sao felix do xingu
# Processing Record 23 of Set 13 | salinas
# Processing Record 24 of Set 13 | rundu
# Processing Record 25 of Set 13 | barsovo
# Processing Record 26 of Set 13 | albacete
# Processing Record 27 of Set 13 | tapiramuta
# Processing Record 28 of Set 13 | santa barbara
# Processing Record 29 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 13 | pasni
# Processing Record 31 of Set 13 | puerto ayacucho
# Processing Record 32 of Set 13 | fort-shevchenko
# Processing Record 33 of Set 13 | hazorasp
# Processing Record 34 of Set 13 | bongandanga
# Processing Record 35 of Set 13 | puerto madryn
# Processing Record 36 of Set 13 | maarianhamina
# Processing Record 37 of Set 13 | soyo
# Processing Record 38 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 13 | scarborough
# Processing Record 40 of Set 13 | shache
# Processing Record 41 of Set 13 | sao joao dos patos
# Processing Record 42 of Set 13 | la asuncion
# Processing Record 43 of Set 13 | rudbar
# Processing Record 44 of Set 13 | akdepe
# Processing Record 45 of Set 13 | yar-sale
# Processing Record 46 of Set 13 | san felipe
# Processing Record 47 of Set 13 | sanford
# Processing Record 48 of Set 13 | bafq
# Processing Record 49 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 50 of Set 13 | acurenam
# Processing Record 1 of Set 14 | sao joao da barra
# Processing Record 2 of Set 14 | voskresenskoye
# Processing Record 3 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 4 of Set 14 | piacabucu
# Processing Record 5 of Set 14 | inhambane
# Processing Record 6 of Set 14 | loharu
# Processing Record 7 of Set 14 | kilindoni
# Processing Record 8 of Set 14 | petukhovo
# Processing Record 9 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 14 | chandia
# Processing Record 11 of Set 14 | freeport
# Processing Record 12 of Set 14 | chandbali
# Processing Record 13 of Set 14 | yining
# Processing Record 14 of Set 14 | san julian
# Processing Record 15 of Set 14 | nurota
# Processing Record 16 of Set 14 | varberg
# Processing Record 17 of Set 14 | kargat
# Processing Record 18 of Set 14 | hobe sound
# Processing Record 19 of Set 14 | nortelandia
# Processing Record 20 of Set 14 | rodrigues alves
# Processing Record 21 of Set 14 | totskoye
# Processing Record 22 of Set 14 | kashary
# Processing Record 23 of Set 14 | bonavista
# Processing Record 24 of Set 14 | san jose
# Processing Record 25 of Set 14 | saryozek
# Processing Record 26 of Set 14 | warri
# Processing Record 27 of Set 14 | santa vitoria do palmar
# Processing Record 28 of Set 14 | macusani
# Processing Record 29 of Set 14 | olonets
# Processing Record 30 of Set 14 | sao joao do piaui
# Processing Record 31 of Set 14 | bozoum
# Processing Record 32 of Set 14 | quchan
# Processing Record 33 of Set 14 | vila nova de milfontes
# Processing Record 34 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 35 of Set 14 | tsogni
# Processing Record 36 of Set 14 | tandalti
# Processing Record 37 of Set 14 | porto novo
# Processing Record 38 of Set 14 | woodstock
# Processing Record 39 of Set 14 | ballina
# Processing Record 40 of Set 14 | groa
# Processing Record 41 of Set 14 | luba
# Processing Record 42 of Set 14 | nybro
# Processing Record 43 of Set 14 | braslav
# City not found. Skipping...
# Processing Record 44 of Set 14 | beyneu
# Processing Record 45 of Set 14 | oistins
# Processing Record 46 of Set 14 | marki
# Processing Record 47 of Set 14 | colonia
# Processing Record 48 of Set 14 | bodmin
# Processing Record 49 of Set 14 | bilgoraj
# Processing Record 50 of Set 14 | san ramon
# Processing Record 1 of Set 15 | tanout
# Processing Record 2 of Set 15 | ardakan
# Processing Record 3 of Set 15 | roros
# Processing Record 4 of Set 15 | vestmanna
# Processing Record 5 of Set 15 | punta cardon
# Processing Record 6 of Set 15 | sinazongwe
# Processing Record 7 of Set 15 | puerto leguizamo
# Processing Record 8 of Set 15 | chishtian mandi
# Processing Record 9 of Set 15 | vila franca do campo
# Processing Record 10 of Set 15 | babol
# Processing Record 11 of Set 15 | antalaha
# Processing Record 12 of Set 15 | rio gallegos
# Processing Record 13 of Set 15 | mogadishu
# Processing Record 14 of Set 15 | donegal
# Processing Record 15 of Set 15 | samana
# Processing Record 16 of Set 15 | calvinia
# Processing Record 17 of Set 15 | staryy nadym
# Processing Record 18 of Set 15 | lusambo
# Processing Record 19 of Set 15 | san rafael
# Processing Record 20 of Set 15 | dulyapino
# Processing Record 21 of Set 15 | nampula
# Processing Record 22 of Set 15 | carndonagh
# Processing Record 23 of Set 15 | bhavnagar
# Processing Record 24 of Set 15 | alakurtti
# Processing Record 25 of Set 15 | olinda
# Processing Record 26 of Set 15 | chaman
# Processing Record 27 of Set 15 | mariakani
# Processing Record 28 of Set 15 | timra
# Processing Record 29 of Set 15 | andros town
# Processing Record 30 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 15 | sabha
# Processing Record 32 of Set 15 | uyuni
# Processing Record 33 of Set 15 | chicama
# Processing Record 34 of Set 15 | dosso
# Processing Record 35 of Set 15 | lima
# Processing Record 36 of Set 15 | lethem
# Processing Record 37 of Set 15 | cumaral
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 671

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df=city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Souillac      MU -20.5167   57.5167     73.78        94          40
# 1     Tasiilaq      GL  65.6145  -37.6368     32.16        97         100
# 2    Sinnamary      GF   5.3833  -52.9500     80.94        89         100
# 3   Georgetown      MY   5.4112  100.3354     82.33        89          20
# 4  Port Alfred      ZA -33.5906   26.8910     62.19        90          23
#
#    Wind Speed Current Description
# 0        5.75          light rain
# 1       24.18                snow
# 2       12.80          light rain
# 3        2.30          few clouds
# 4       11.43          few clouds

# %%
# Create the output file (CSV).
output_data_file = "weatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
